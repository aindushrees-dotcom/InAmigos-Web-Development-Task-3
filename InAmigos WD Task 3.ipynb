# %%
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8"/>
<meta name="viewport" content="width=device-width, initial-scale=1.0"/>
<title>BrightPath Foundation — Empowering Futures</title>
<link href="https://fonts.googleapis.com/css2?family=Playfair+Display:wght@400;700;900&family=DM+Sans:wght@300;400;500&display=swap" rel="stylesheet"/>
<style>
  :root {
    --ink: #0d0d0d;
    --cream: #f5f0e8;
    --warm: #e8dcc8;
    --gold: #c9932a;
    --gold-light: #f0c96b;
    --rust: #b84a2e;
    --sage: #4a7c59;
    --sage-light: #6bab7e;
    --text-body: #3a3530;
    --text-muted: #7a7065;
  }

  *, *::before, *::after { box-sizing: border-box; margin: 0; padding: 0; }

  html { scroll-behavior: smooth; }

  body {
    font-family: 'DM Sans', sans-serif;
    background: var(--cream);
    color: var(--text-body);
    overflow-x: hidden;
  }

  /* ─── NAV ─── */
  nav {
    position: fixed; top: 0; left: 0; right: 0; z-index: 999;
    display: flex; justify-content: space-between; align-items: center;
    padding: 18px 60px;
    background: rgba(245,240,232,0.92);
    backdrop-filter: blur(12px);
    border-bottom: 1px solid rgba(201,147,42,0.18);
    animation: slideDown .6s ease both;
  }
  @keyframes slideDown { from { transform: translateY(-100%); opacity: 0; } to { transform: translateY(0); opacity: 1; } }

  .nav-logo {
    font-family: 'Playfair Display', serif;
    font-size: 1.5rem; font-weight: 900;
    color: var(--ink);
    letter-spacing: -0.5px;
  }
  .nav-logo span { color: var(--gold); }

  .nav-links { display: flex; gap: 36px; list-style: none; }
  .nav-links a {
    font-size: .88rem; font-weight: 500; letter-spacing: .04em;
    text-transform: uppercase; text-decoration: none;
    color: var(--text-muted);
    transition: color .2s;
  }
  .nav-links a:hover { color: var(--gold); }

  .nav-cta {
    background: var(--ink); color: var(--cream) !important;
    padding: 9px 22px; border-radius: 2px;
    transition: background .2s !important;
  }
  .nav-cta:hover { background: var(--gold) !important; color: var(--ink) !important; }

  /* ─── HERO ─── */
  #hero {
    min-height: 100vh;
    display: grid; grid-template-columns: 1fr 1fr; align-items: center;
    padding: 120px 60px 60px;
    position: relative; overflow: hidden;
  }

  .hero-bg-shapes {
    position: absolute; inset: 0; pointer-events: none; z-index: 0;
  }
  .shape-circle {
    position: absolute; border-radius: 50%;
    background: radial-gradient(circle, rgba(201,147,42,0.15) 0%, transparent 70%);
  }
  .s1 { width: 600px; height: 600px; right: -100px; top: -100px; }
  .s2 { width: 300px; height: 300px; left: 100px; bottom: 50px; background: radial-gradient(circle, rgba(74,124,89,0.12) 0%, transparent 70%); }

  .hero-content { position: relative; z-index: 1; animation: fadeUp .9s .2s ease both; }
  @keyframes fadeUp { from { transform: translateY(40px); opacity: 0; } to { transform: translateY(0); opacity: 1; } }

  .hero-tag {
    display: inline-block;
    font-size: .78rem; font-weight: 500; letter-spacing: .12em; text-transform: uppercase;
    color: var(--gold);
    border: 1px solid var(--gold);
    padding: 5px 14px; border-radius: 20px; margin-bottom: 24px;
  }

  .hero-title {
    font-family: 'Playfair Display', serif;
    font-size: clamp(2.8rem, 5vw, 4.5rem);
    font-weight: 900; line-height: 1.08;
    color: var(--ink);
    margin-bottom: 24px;
  }
  .hero-title em { font-style: italic; color: var(--gold); }

  .hero-desc {
    font-size: 1.05rem; line-height: 1.75;
    color: var(--text-muted); max-width: 480px;
    margin-bottom: 40px;
  }

  .hero-btns { display: flex; gap: 16px; flex-wrap: wrap; }

  .btn-primary {
    background: var(--gold); color: var(--ink);
    padding: 14px 32px; font-weight: 600; font-size: .92rem;
    border: none; border-radius: 2px; cursor: pointer;
    text-decoration: none; display: inline-block;
    transition: transform .2s, box-shadow .2s;
  }
  .btn-primary:hover { transform: translateY(-2px); box-shadow: 0 8px 24px rgba(201,147,42,0.35); }

  .btn-outline {
    background: transparent; color: var(--ink);
    padding: 13px 32px; font-weight: 500; font-size: .92rem;
    border: 1.5px solid var(--ink); border-radius: 2px; cursor: pointer;
    text-decoration: none; display: inline-block;
    transition: background .2s, color .2s;
  }
  .btn-outline:hover { background: var(--ink); color: var(--cream); }

  .hero-visual {
    position: relative; z-index: 1; display: flex; justify-content: center; align-items: center;
    animation: fadeUp .9s .4s ease both;
  }

  .hero-card-stack { position: relative; width: 360px; height: 420px; }

  .hcard {
    position: absolute; border-radius: 12px; padding: 28px;
    box-shadow: 0 20px 60px rgba(0,0,0,0.12);
    transition: transform .3s;
  }
  .hcard:hover { transform: translateY(-6px); }

  .hcard-1 {
    background: var(--sage); color: white;
    width: 280px; top: 0; left: 40px;
  }
  .hcard-2 {
    background: var(--ink); color: var(--cream);
    width: 260px; top: 160px; left: 0;
  }
  .hcard-3 {
    background: var(--gold); color: var(--ink);
    width: 200px; top: 200px; right: 0;
    font-weight: 700; text-align: center; padding: 24px;
  }

  .hcard-label { font-size: .72rem; text-transform: uppercase; letter-spacing: .1em; opacity: .7; margin-bottom: 8px; }
  .hcard-num { font-family: 'Playfair Display', serif; font-size: 2.6rem; font-weight: 900; line-height: 1; }
  .hcard-sub { font-size: .85rem; opacity: .8; margin-top: 6px; }
  .hcard-icon { font-size: 2rem; margin-bottom: 10px; }

  /* ─── STATS BAR ─── */
  .stats-bar {
    background: var(--ink); color: var(--cream);
    display: flex; justify-content: space-around;
    padding: 40px 60px; flex-wrap: wrap; gap: 30px;
  }
  .stat-item { text-align: center; }
  .stat-num {
    font-family: 'Playfair Display', serif;
    font-size: 2.8rem; font-weight: 900; color: var(--gold-light);
    display: block; line-height: 1;
  }
  .stat-label { font-size: .82rem; letter-spacing: .06em; text-transform: uppercase; opacity: .65; margin-top: 6px; }

  /* ─── SECTION SHARED ─── */
  section { padding: 100px 60px; }
  .section-tag {
    font-size: .78rem; font-weight: 500; letter-spacing: .12em; text-transform: uppercase;
    color: var(--gold); display: block; margin-bottom: 12px;
  }
  .section-title {
    font-family: 'Playfair Display', serif;
    font-size: clamp(2rem, 3.5vw, 2.8rem); font-weight: 900;
    color: var(--ink); line-height: 1.15; margin-bottom: 18px;
  }
  .section-desc { font-size: 1.02rem; line-height: 1.75; color: var(--text-muted); max-width: 560px; }

  /* ─── ABOUT ─── */
  #about {
    background: white;
    display: grid; grid-template-columns: 1fr 1fr; gap: 80px; align-items: center;
  }

  .about-image-block { position: relative; }
  .about-main-img {
    width: 100%; border-radius: 8px;
    background: linear-gradient(135deg, var(--sage) 0%, var(--sage-light) 100%);
    height: 420px; display: flex; flex-direction: column;
    align-items: center; justify-content: center;
    font-size: 5rem; gap: 16px;
  }
  .about-main-img p {
    font-family: 'Playfair Display', serif;
    font-size: 1.4rem; color: white; font-weight: 700;
  }
  .about-badge {
    position: absolute; bottom: -20px; right: -20px;
    background: var(--gold); color: var(--ink);
    padding: 20px 24px; border-radius: 6px;
    box-shadow: 0 10px 30px rgba(201,147,42,0.3);
    text-align: center;
  }
  .about-badge strong { font-family: 'Playfair Display', serif; font-size: 2rem; display: block; }
  .about-badge span { font-size: .78rem; font-weight: 500; }

  .about-values { display: flex; flex-direction: column; gap: 20px; margin-top: 36px; }
  .value-item { display: flex; gap: 16px; align-items: flex-start; }
  .value-dot { width: 10px; height: 10px; border-radius: 50%; background: var(--gold); margin-top: 6px; flex-shrink: 0; }
  .value-item h4 { font-weight: 600; margin-bottom: 4px; }
  .value-item p { font-size: .9rem; color: var(--text-muted); line-height: 1.6; }

  /* ─── PROGRAMS / SERVICES ─── */
  #services { background: var(--cream); }
  .services-header { text-align: center; margin-bottom: 60px; }
  .services-header .section-desc { margin: 0 auto; }

  .services-grid {
    display: grid; grid-template-columns: repeat(3, 1fr); gap: 28px;
    margin-top: 50px;
  }

  .service-card {
    background: white; border-radius: 8px;
    padding: 36px 32px;
    border: 1px solid rgba(201,147,42,0.12);
    transition: transform .3s, box-shadow .3s;
    position: relative; overflow: hidden;
  }
  .service-card::before {
    content: ''; position: absolute; bottom: 0; left: 0; right: 0; height: 3px;
    background: var(--gold); transform: scaleX(0); transform-origin: left;
    transition: transform .3s;
  }
  .service-card:hover { transform: translateY(-6px); box-shadow: 0 20px 50px rgba(0,0,0,0.08); }
  .service-card:hover::before { transform: scaleX(1); }

  .service-icon { font-size: 2.4rem; margin-bottom: 20px; display: block; }
  .service-card h3 {
    font-family: 'Playfair Display', serif; font-size: 1.25rem;
    margin-bottom: 12px; color: var(--ink);
  }
  .service-card p { font-size: .9rem; line-height: 1.7; color: var(--text-muted); }
  .service-tag {
    display: inline-block; margin-top: 16px;
    font-size: .72rem; font-weight: 600; text-transform: uppercase;
    letter-spacing: .08em; color: var(--sage);
    background: rgba(74,124,89,0.1); padding: 4px 10px; border-radius: 20px;
  }

  /* ─── IMPACT ─── */
  #impact {
    background: var(--ink); color: var(--cream);
  }
  .impact-header { margin-bottom: 60px; }
  .impact-header .section-title { color: var(--cream); }
  .impact-header .section-tag { color: var(--gold-light); }

  .impact-grid { display: grid; grid-template-columns: 1fr 1fr; gap: 30px; }

  .impact-card {
    background: rgba(255,255,255,0.05); border-radius: 8px;
    padding: 32px; border: 1px solid rgba(255,255,255,0.08);
    transition: border-color .3s;
  }
  .impact-card:hover { border-color: var(--gold); }
  .impact-card-num {
    font-family: 'Playfair Display', serif;
    font-size: 3rem; font-weight: 900; color: var(--gold-light);
    display: block; margin-bottom: 8px;
  }
  .impact-card h4 { font-size: 1.05rem; margin-bottom: 10px; }
  .impact-card p { font-size: .88rem; line-height: 1.65; opacity: .65; }

  .impact-quote {
    grid-column: 1 / -1; margin-top: 20px;
    background: rgba(201,147,42,0.1); border-left: 3px solid var(--gold);
    padding: 28px 32px; border-radius: 0 8px 8px 0;
  }
  .impact-quote blockquote {
    font-family: 'Playfair Display', serif; font-size: 1.3rem; font-style: italic;
    line-height: 1.6; color: var(--gold-light);
  }
  .impact-quote cite { display: block; margin-top: 12px; font-size: .85rem; opacity: .65; font-style: normal; }

  /* ─── TEAM ─── */
  #team { background: white; }
  .team-header { text-align: center; margin-bottom: 60px; }
  .team-header .section-desc { margin: 0 auto; }

  .team-grid { display: grid; grid-template-columns: repeat(4, 1fr); gap: 28px; }

  .team-card { text-align: center; }
  .team-avatar {
    width: 110px; height: 110px; border-radius: 50%;
    margin: 0 auto 16px; font-size: 2.5rem;
    display: flex; align-items: center; justify-content: center;
    border: 3px solid var(--warm);
    transition: border-color .3s;
  }
  .team-card:hover .team-avatar { border-color: var(--gold); }
  .ta-1 { background: linear-gradient(135deg, #d4e8da, #a8ccb4); }
  .ta-2 { background: linear-gradient(135deg, #e8d9c0, #d4b98a); }
  .ta-3 { background: linear-gradient(135deg, #c8d8e8, #9ab8d0); }
  .ta-4 { background: linear-gradient(135deg, #e8c8d0, #d09aaa); }

  .team-card h4 { font-weight: 600; margin-bottom: 4px; }
  .team-card span { font-size: .82rem; color: var(--gold); font-weight: 500; }
  .team-card p { font-size: .85rem; color: var(--text-muted); margin-top: 8px; line-height: 1.55; }

  /* ─── DONATE / CTA ─── */
  #donate {
    background: linear-gradient(135deg, var(--gold) 0%, var(--rust) 100%);
    color: white; text-align: center;
    padding: 100px 60px;
  }
  #donate .section-title { color: white; margin: 0 auto 16px; }
  #donate .section-desc { color: rgba(255,255,255,0.85); margin: 0 auto 40px; }
  .donate-amounts { display: flex; gap: 16px; justify-content: center; flex-wrap: wrap; margin-bottom: 40px; }
  .donate-chip {
    background: rgba(255,255,255,0.2); color: white;
    padding: 10px 24px; border-radius: 30px; cursor: pointer;
    font-weight: 600; font-size: .92rem; border: 1.5px solid rgba(255,255,255,0.4);
    transition: background .2s;
  }
  .donate-chip:hover, .donate-chip.active { background: rgba(255,255,255,0.35); }
  .btn-white {
    background: white; color: var(--rust);
    padding: 16px 44px; font-weight: 700; font-size: 1rem;
    border: none; border-radius: 2px; cursor: pointer;
    transition: transform .2s, box-shadow .2s;
    text-decoration: none; display: inline-block;
  }
  .btn-white:hover { transform: translateY(-3px); box-shadow: 0 12px 30px rgba(0,0,0,0.2); }

  /* ─── CONTACT ─── */
  #contact {
    background: var(--cream);
    display: grid; grid-template-columns: 1fr 1fr; gap: 80px; align-items: start;
  }
  .contact-info h2 { font-family: 'Playfair Display', serif; font-size: 2rem; margin-bottom: 16px; }
  .contact-info p { color: var(--text-muted); line-height: 1.7; margin-bottom: 36px; }
  .contact-item { display: flex; gap: 16px; align-items: center; margin-bottom: 20px; }
  .contact-icon { width: 44px; height: 44px; background: white; border-radius: 8px; display: flex; align-items: center; justify-content: center; font-size: 1.2rem; box-shadow: 0 2px 12px rgba(0,0,0,0.06); flex-shrink: 0; }
  .contact-item div strong { display: block; font-size: .88rem; margin-bottom: 2px; }
  .contact-item div span { font-size: .85rem; color: var(--text-muted); }

  .contact-form { background: white; padding: 40px; border-radius: 10px; box-shadow: 0 8px 40px rgba(0,0,0,0.06); }
  .form-group { margin-bottom: 20px; }
  .form-group label { display: block; font-size: .82rem; font-weight: 600; text-transform: uppercase; letter-spacing: .06em; color: var(--text-muted); margin-bottom: 7px; }
  .form-group input, .form-group textarea, .form-group select {
    width: 100%; padding: 12px 16px;
    border: 1.5px solid rgba(0,0,0,0.1); border-radius: 4px;
    font-family: 'DM Sans', sans-serif; font-size: .92rem; color: var(--ink);
    background: var(--cream); transition: border-color .2s;
    outline: none;
  }
  .form-group input:focus, .form-group textarea:focus { border-color: var(--gold); }
  .form-group textarea { resize: vertical; min-height: 120px; }
  .form-row { display: grid; grid-template-columns: 1fr 1fr; gap: 16px; }

  /* ─── FOOTER ─── */
  footer {
    background: var(--ink); color: var(--cream);
    padding: 60px 60px 30px;
  }
  .footer-top { display: grid; grid-template-columns: 2fr 1fr 1fr 1fr; gap: 50px; margin-bottom: 50px; }
  .footer-brand .nav-logo { font-size: 1.6rem; }
  .footer-brand p { font-size: .88rem; line-height: 1.7; opacity: .6; margin-top: 14px; max-width: 280px; }
  .footer-social { display: flex; gap: 10px; margin-top: 20px; }
  .social-btn { width: 36px; height: 36px; border-radius: 50%; background: rgba(255,255,255,0.08); display: flex; align-items: center; justify-content: center; font-size: .9rem; cursor: pointer; transition: background .2s; }
  .social-btn:hover { background: var(--gold); }

  .footer-col h5 { font-size: .82rem; text-transform: uppercase; letter-spacing: .1em; color: var(--gold-light); margin-bottom: 18px; }
  .footer-col ul { list-style: none; }
  .footer-col li { margin-bottom: 10px; }
  .footer-col a { font-size: .88rem; opacity: .6; text-decoration: none; color: var(--cream); transition: opacity .2s; }
  .footer-col a:hover { opacity: 1; }

  .footer-bottom { border-top: 1px solid rgba(255,255,255,0.08); padding-top: 24px; display: flex; justify-content: space-between; align-items: center; flex-wrap: wrap; gap: 12px; }
  .footer-bottom p { font-size: .82rem; opacity: .45; }

  /* Animations on scroll */
  .reveal { opacity: 0; transform: translateY(30px); transition: opacity .7s ease, transform .7s ease; }
  .reveal.visible { opacity: 1; transform: translateY(0); }

  @media (max-width: 900px) {
    nav { padding: 16px 24px; }
    .nav-links { display: none; }
    #hero { grid-template-columns: 1fr; padding: 100px 24px 60px; gap: 50px; }
    #about, #contact { grid-template-columns: 1fr; padding: 70px 24px; }
    .services-grid, .impact-grid { grid-template-columns: 1fr; }
    .team-grid { grid-template-columns: 1fr 1fr; }
    .footer-top { grid-template-columns: 1fr 1fr; }
    section { padding: 70px 24px; }
    .stats-bar { padding: 30px 24px; }
    #donate { padding: 70px 24px; }
    footer { padding: 50px 24px 24px; }
  }
</style>
</head>
<body>

<!-- NAV -->
<nav>
  <div class="nav-logo">Bright<span>Path</span></div>
  <ul class="nav-links">
    <li><a href="#hero">Home</a></li>
    <li><a href="#about">About</a></li>
    <li><a href="#services">Programs</a></li>
    <li><a href="#impact">Impact</a></li>
    <li><a href="#team">Team</a></li>
    <li><a href="#contact">Contact</a></li>
    <li><a href="#donate" class="nav-cta">Donate</a></li>
  </ul>
</nav>

<!-- HERO -->
<section id="hero">
  <div class="hero-bg-shapes">
    <div class="shape-circle s1"></div>
    <div class="shape-circle s2"></div>
  </div>
  <div class="hero-content">
    <span class="hero-tag">✦ Est. 2015 — Bangalore, India</span>
    <h1 class="hero-title">
      Lighting the Path to <em>Brighter</em> Futures
    </h1>
    <p class="hero-desc">BrightPath Foundation empowers underserved youth through quality education, skill development, and community support — because every child deserves the chance to thrive.</p>
    <div class="hero-btns">
      <a href="#services" class="btn-primary">Explore Our Programs</a>
      <a href="#donate" class="btn-outline">Make a Difference</a>
    </div>
  </div>
  <div class="hero-visual">
    <div class="hero-card-stack">
      <div class="hcard hcard-1">
        <div class="hcard-label">Children Educated</div>
        <div class="hcard-num">12,400+</div>
        <div class="hcard-sub">Across 8 districts</div>
      </div>
      <div class="hcard hcard-2">
        <div class="hcard-label">Active Programs</div>
        <div class="hcard-num">24</div>
        <div class="hcard-sub">Running this year</div>
      </div>
      <div class="hcard hcard-3">
        <div class="hcard-icon">🏆</div>
        <div>Top NGO<br/>Karnataka 2024</div>
      </div>
    </div>
  </div>
</section>

<!-- STATS BAR -->
<div class="stats-bar reveal">
  <div class="stat-item">
    <span class="stat-num">₹2.4Cr</span>
    <div class="stat-label">Funds Distributed</div>
  </div>
  <div class="stat-item">
    <span class="stat-num">340+</span>
    <div class="stat-label">Volunteers Engaged</div>
  </div>
  <div class="stat-item">
    <span class="stat-num">98%</span>
    <div class="stat-label">Retention Rate</div>
  </div>
  <div class="stat-item">
    <span class="stat-num">56</span>
    <div class="stat-label">Partner Schools</div>
  </div>
  <div class="stat-item">
    <span class="stat-num">9 yrs</span>
    <div class="stat-label">Of Dedicated Service</div>
  </div>
</div>

<!-- ABOUT -->
<section id="about">
  <div class="about-image-block reveal">
    <div class="about-main-img">
      <span>🌱</span>
      <p>Growing Together</p>
    </div>
    <div class="about-badge">
      <strong>2015</strong>
      <span>Founded in Bangalore</span>
    </div>
  </div>
  <div class="reveal">
    <span class="section-tag">Our Story</span>
    <h2 class="section-title">A Community Built on Belief</h2>
    <p class="section-desc">BrightPath Foundation was born from one simple belief: geography and circumstance should never limit a child's potential. We work in the margins — in slums, rural clusters, and migrant settlements — ensuring no child is left behind.</p>
    <div class="about-values">
      <div class="value-item">
        <div class="value-dot"></div>
        <div>
          <h4>Holistic Education</h4>
          <p>Beyond textbooks — we nurture critical thinking, creativity, and confidence in every learner.</p>
        </div>
      </div>
      <div class="value-item">
        <div class="value-dot"></div>
        <div>
          <h4>Community First</h4>
          <p>We work with families, not just students — because transformation is always collective.</p>
        </div>
      </div>
      <div class="value-item">
        <div class="value-dot"></div>
        <div>
          <h4>Transparent Impact</h4>
          <p>Every rupee donated is tracked, reported, and put to work where it matters most.</p>
        </div>
      </div>
    </div>
  </div>
</section>

<!-- PROGRAMS -->
<section id="services">
  <div class="services-header reveal">
    <span class="section-tag">What We Do</span>
    <h2 class="section-title">Programs That Transform Lives</h2>
    <p class="section-desc">Our six core programs address education, health, skills, and digital literacy — covering the full arc of a child's development.</p>
  </div>
  <div class="services-grid">
    <div class="service-card reveal">
      <span class="service-icon">📚</span>
      <h3>After-School Learning</h3>
      <p>Daily tutoring and mentorship sessions for students in Grades 1–10, focusing on foundational literacy and numeracy in local languages and English.</p>
      <span class="service-tag">Education</span>
    </div>
    <div class="service-card reveal">
      <span class="service-icon">💻</span>
      <h3>Digital Literacy Labs</h3>
      <p>Tablet-based computer labs in low-income schools teach coding, internet safety, and basic digital skills to students who've never touched a screen.</p>
      <span class="service-tag">Technology</span>
    </div>
    <div class="service-card reveal">
      <span class="service-icon">🎨</span>
      <h3>Arts & Expression</h3>
      <p>Weekly workshops in painting, music, dance, and drama let students build self-confidence and emotional intelligence through creative expression.</p>
      <span class="service-tag">Wellbeing</span>
    </div>
    <div class="service-card reveal">
      <span class="service-icon">🩺</span>
      <h3>Health & Nutrition</h3>
      <p>Monthly health camps, nutritional support, and hygiene workshops ensure students are physically ready to learn — because hungry children can't focus.</p>
      <span class="service-tag">Health</span>
    </div>
    <div class="service-card reveal">
      <span class="service-icon">👩‍💼</span>
      <h3>Women's Skilling</h3>
      <p>Vocational training in tailoring, food processing, and handicrafts empowers mothers and young women with income-generating skills.</p>
      <span class="service-tag">Livelihood</span>
    </div>
    <div class="service-card reveal">
      <span class="service-icon">🏫</span>
      <h3>School Adoption</h3>
      <p>We partner with government schools to upgrade infrastructure, train teachers, and supply learning materials to transform underfunded classrooms.</p>
      <span class="service-tag">Infrastructure</span>
    </div>
  </div>
</section>

<!-- IMPACT -->
<section id="impact">
  <div class="impact-header reveal">
    <span class="section-tag">Numbers That Matter</span>
    <h2 class="section-title">Our Impact in 2024</h2>
  </div>
  <div class="impact-grid">
    <div class="impact-card reveal">
      <span class="impact-card-num">94%</span>
      <h4>School Completion Rate</h4>
      <p>Among enrolled students in our after-school program — versus a 72% district average for similar communities.</p>
    </div>
    <div class="impact-card reveal">
      <span class="impact-card-num">3,200</span>
      <h4>Girls Supported in 2024</h4>
      <p>Through a dedicated girls' education fund ensuring that gender is never a barrier to learning.</p>
    </div>
    <div class="impact-card reveal">
      <span class="impact-card-num">870</span>
      <h4>Women Trained & Employed</h4>
      <p>Through our skilling program — 64% reported income growth within 6 months of completing training.</p>
    </div>
    <div class="impact-card reveal">
      <span class="impact-card-num">18</span>
      <h4>Digital Labs Installed</h4>
      <p>Across government schools — giving 4,000+ students their first access to computers and the internet.</p>
    </div>
    <div class="impact-quote reveal">
      <blockquote>"For the first time, my daughter came home excited about school. Not just to go — but to learn."</blockquote>
      <cite>— Kavitha R., Parent, Yelahanka Community Centre</cite>
    </div>
  </div>
</section>

<!-- TEAM -->
<section id="team">
  <div class="team-header reveal">
    <span class="section-tag">The People Behind the Mission</span>
    <h2 class="section-title">Meet Our Team</h2>
    <p class="section-desc">A passionate group of educators, technologists, and community builders united by one goal — giving every child a fair start.</p>
  </div>
  <div class="team-grid">
    <div class="team-card reveal">
      <div class="team-avatar ta-1">🧑‍🏫</div>
      <h4>Arjun Nair</h4>
      <span>Founder & CEO</span>
      <p>Former IIT-B professor who left academia to build ground-level impact. 18 years in education.</p>
    </div>
    <div class="team-card reveal">
      <div class="team-avatar ta-2">👩‍💼</div>
      <h4>Meera Krishnan</h4>
      <span>Programs Director</span>
      <p>Led social impact at UNICEF India for 8 years. Drives BrightPath's curriculum and outreach strategy.</p>
    </div>
    <div class="team-card reveal">
      <div class="team-avatar ta-3">👨‍💻</div>
      <h4>Rahul Shetty</h4>
      <span>Tech & Innovation Lead</span>
      <p>Ex-Google engineer building our digital labs initiative and ed-tech tools for low-bandwidth environments.</p>
    </div>
    <div class="team-card reveal">
      <div class="team-avatar ta-4">👩‍🎨</div>
      <h4>Divya Rao</h4>
      <span>Community & Outreach</span>
      <p>Grassroots organizer who has mobilized 340+ volunteers across 12 neighborhoods in Bangalore.</p>
    </div>
  </div>
</section>

<!-- DONATE CTA -->
<section id="donate">
  <span class="section-tag" style="color:rgba(255,255,255,0.7)">Be the Change</span>
  <h2 class="section-title" style="max-width:600px;">Your Support Changes a Child's Story</h2>
  <p class="section-desc">A small contribution makes a big difference. Choose an amount — or donate what you can.</p>
  <div class="donate-amounts">
    <div class="donate-chip">₹500 — School supplies</div>
    <div class="donate-chip active">₹1,000 — One month tutoring</div>
    <div class="donate-chip">₹5,000 — Sponsor a lab session</div>
    <div class="donate-chip">₹10,000 — Full scholarship</div>
  </div>
  <a href="#contact" class="btn-white">Donate Now →</a>
</section>

<!-- CONTACT -->
<section id="contact">
  <div class="reveal">
    <span class="section-tag">Get in Touch</span>
    <h2 class="section-title">Let's Build Something Together</h2>
    <p style="color:var(--text-muted); line-height:1.7; margin-bottom:36px;">Whether you want to volunteer, partner, or simply learn more — we'd love to hear from you.</p>
    <div class="contact-item">
      <div class="contact-icon">📍</div>
      <div><strong>Address</strong><span>#45, 3rd Cross, HSR Layout, Bangalore – 560102</span></div>
    </div>
    <div class="contact-item">
      <div class="contact-icon">📞</div>
      <div><strong>Phone</strong><span>+91 98765 43210</span></div>
    </div>
    <div class="contact-item">
      <div class="contact-icon">✉️</div>
      <div><strong>Email</strong><span>hello@brightpathfoundation.org</span></div>
    </div>
    <div class="contact-item">
      <div class="contact-icon">🕐</div>
      <div><strong>Office Hours</strong><span>Mon – Sat, 9 AM to 6 PM IST</span></div>
    </div>
  </div>
  <div class="contact-form reveal">
    <h3 style="font-family:'Playfair Display',serif; font-size:1.4rem; margin-bottom:24px;">Send Us a Message</h3>
    <div class="form-row">
      <div class="form-group">
        <label>First Name</label>
        <input type="text" placeholder="Indushree"/>
      </div>
      <div class="form-group">
        <label>Last Name</label>
        <input type="text" placeholder="K"/>
      </div>
    </div>
    <div class="form-group">
      <label>Email Address</label>
      <input type="email" placeholder="you@email.com"/>
    </div>
    <div class="form-group">
      <label>I want to</label>
      <select>
        <option>Volunteer with BrightPath</option>
        <option>Make a Donation</option>
        <option>Partner / Collaborate</option>
        <option>Learn About Programs</option>
        <option>Something Else</option>
      </select>
    </div>
    <div class="form-group">
      <label>Message</label>
      <textarea placeholder="Tell us how you'd like to get involved…"></textarea>
    </div>
    <button class="btn-primary" style="width:100%; text-align:center; padding:15px;">Send Message →</button>
  </div>
</section>

<!-- FOOTER -->
<footer>
  <div class="footer-top">
    <div class="footer-brand">
      <div class="nav-logo">Bright<span>Path</span></div>
      <p>Empowering underserved youth through education, technology, and community — one child at a time.</p>
      <div class="footer-social">
        <div class="social-btn">𝕏</div>
        <div class="social-btn">in</div>
        <div class="social-btn">f</div>
        <div class="social-btn">▶</div>
      </div>
    </div>
    <div class="footer-col">
      <h5>Programs</h5>
      <ul>
        <li><a href="#">After-School</a></li>
        <li><a href="#">Digital Labs</a></li>
        <li><a href="#">Arts & Expression</a></li>
        <li><a href="#">Health Camps</a></li>
        <li><a href="#">Women's Skilling</a></li>
      </ul>
    </div>
    <div class="footer-col">
      <h5>Organization</h5>
      <ul>
        <li><a href="#">Our Story</a></li>
        <li><a href="#">Leadership Team</a></li>
        <li><a href="#">Annual Reports</a></li>
        <li><a href="#">Careers</a></li>
        <li><a href="#">Press Kit</a></li>
      </ul>
    </div>
    <div class="footer-col">
      <h5>Get Involved</h5>
      <ul>
        <li><a href="#">Donate</a></li>
        <li><a href="#">Volunteer</a></li>
        <li><a href="#">Corporate CSR</a></li>
        <li><a href="#">Events</a></li>
        <li><a href="#">Newsletter</a></li>
      </ul>
    </div>
  </div>
  <div class="footer-bottom">
    <p>© 2024 BrightPath Foundation. All rights reserved. Registered NGO under Sec. 12A & 80G.</p>
    <p>Built with ❤️ using AI-powered design tools · Bangalore, India</p>
  </div>
</footer>

<script>
  // Scroll reveal
  const reveals = document.querySelectorAll('.reveal');
  const observer = new IntersectionObserver((entries) => {
    entries.forEach(e => { if (e.isIntersecting) { e.target.classList.add('visible'); } });
  }, { threshold: 0.1 });
  reveals.forEach(el => observer.observe(el));

  // Donate chip toggle
  document.querySelectorAll('.donate-chip').forEach(chip => {
    chip.addEventListener('click', () => {
      document.querySelectorAll('.donate-chip').forEach(c => c.classList.remove('active'));
      chip.classList.add('active');
    });
  });

  // Smooth nav active state
  const sections = document.querySelectorAll('section[id]');
  window.addEventListener('scroll', () => {
    let current = '';
    sections.forEach(s => { if (window.scrollY >= s.offsetTop - 100) current = s.id; });
    document.querySelectorAll('.nav-links a').forEach(a => {
      a.style.color = a.getAttribute('href') === `#${current}` ? 'var(--gold)' : '';
    });
  });
</script>
</body>
</html>
